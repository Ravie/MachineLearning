# %% [markdown]
# # Быстрый старт в анализ данных
#
# **с помощью `Pandas` и `Scikit-learn`,**
# **а также `numpy` и `matplotlib`**
#
# - `numpy` – матричные операции
# - `matplotlib` – научная графика
# - `pandas` – таблицы (DataFrame) для анализа данных
# - `scikit-learn` – алгоритмы машинного обучения

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
#url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data'
#data = pd.read_csv(url, sep = ', ', engine='python')
data = pd.read_csv('insurance.csv', sep = ',', engine = 'python')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# 5      31  female  25.740         0     no  southeast   3756.62160
# 6      46  female  33.440         1     no  southeast   8240.58960
# 7      37  female  27.740         3     no  northwest   7281.50560
# 8      37    male  29.830         2     no  northeast   6406.41070
# 9      60  female  25.840         0     no  northwest  28923.13692
# 10     25    male  26.220         0     no  northeast   2721.32080
# 11     62  female  26.290         0    yes  southeast  27808.72510
# 12     23    male  34.400         0     no  southwest   1826.84300
# ...

# %%
print(data)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# 5      31  female  25.740         0     no  southeast   3756.62160
# 6      46  female  33.440         1     no  southeast   8240.58960
# 7      37  female  27.740         3     no  northwest   7281.50560
# 8      37    male  29.830         2     no  northeast   6406.41070
# 9      60  female  25.840         0     no  northwest  28923.13692
# 10     25    male  26.220         0     no  northeast   2721.32080
# 11     62  female  26.290         0    yes  southeast  27808.72510
# 12     23    male  34.400         0     no  southwest   1826.84300
# ...

# %%
#data.columns = [u'age', u'workclass', u'fnlwgt', u'education', u'education-num',
#       u'marital-status', u'occupation', u'relationship', u'race', u'sex',
#       u'capital-gain', u'capital-loss', u'hours-per-week', u'native-country',
#       u'class']

# %%
data.head()
# Out:
# <bound method NDFrame.describe of 0       southwest
# 1       southeast
# 2       southeast
# 3       northwest
# 4       northwest
# 5       southeast
# 6       southeast
# 7       northwest
# 8       northeast
# 9       northwest
# 10      northeast
# 11      southeast
# 12      southwest
# 13      southeast
# 14      southeast
# 15      southwest
# 16      northeast
# 17      northeast
# 18      southwest
# 19      southwest
# 20      northeast
# 21      southwest
# 22      southeast
# 23      northeast
# 24      northwest
# 25      southeast
# 26      northeast
# 27      northwest
# 28      northwest
# 29      southwest
#           ...
# 1308    southwest
# 1309    southwest
# 1310    northwest
# 1311    northwest
# 1312    southwest
# 1313    southwest
# 1314    northwest
# 1315    northeast
# 1316    southwest
# 1317    southeast
# 1318    northeast
# 1319    northwest
# 1320    northwest
# 1321    northeast
# 1322    southeast
# 1323    southeast
# 1324    northwest
# ...

# %%
data.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %% [markdown]
# Columns:
# age: age of primary beneficiary
# sex: insurance contractor gender, female, male
# bmi: Body mass index, providing an understanding of body, weights that are relatively high or low relative to height, objective index of body weight (kg / m ^ 2) using the ratio of height to weight, ideally 18.5 to 24.9
# children: Number of children covered by health insurance / Number of dependents
# smoker: Smoking
# region: the beneficiary's residential area in the US, northeast, southeast, southwest, northwest.
# charges: Individual medical costs billed by health insurance

# %%
print(data.shape)
print(data.columns)
# Out:
# (1338, 7)
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
#data.columns = []

# %%
data.index
# Out:
# RangeIndex(start=0, stop=1338, step=1)

# %%
data.at[2, 'sex']
# Out:
# 'male'

# %%
data['bmi']
# Out:
# 0       27.900
# 1       33.770
# 2       33.000
# 3       22.705
# 4       28.880
# 5       25.740
# 6       33.440
# 7       27.740
# 8       29.830
# 9       25.840
# 10      26.220
# 11      26.290
# 12      34.400
# 13      39.820
# 14      42.130
# 15      24.600
# 16      30.780
# 17      23.845
# 18      40.300
# 19      35.300
# 20      36.005
# 21      32.400
# 22      34.100
# 23      31.920
# 24      28.025
# 25      27.720
# 26      23.085
# 27      32.775
# 28      17.385
# 29      36.300
#          ...
# 1308    30.200
# 1309    32.200
# 1310    26.315
# 1311    26.695
# 1312    42.900
# 1313    34.700
# 1314    23.655
# 1315    28.310
# 1316    20.600
# 1317    53.130
# 1318    39.710
# 1319    26.315
# 1320    31.065
# 1321    26.695
# 1322    38.830
# 1323    40.370
# 1324    25.935
# 1325    33.535
# 1326    32.870
# 1327    30.030
# 1328    24.225
# 1329    38.600
# 1330    25.740
# 1331    33.400
# 1332    44.700
# 1333    30.970
# 1334    31.920
# ...

# %%
data['bmi'][3]
# Out:
# 22.705

# %%
data['charges'].dtype.name
# Out:
# 'float64'

# %%
type(data['bmi'][3])
# Out:
# numpy.float64

# %%
type(data['bmi'])
# Out:
# pandas.core.series.Series

# %%
data[['bmi', 'region']].head()
# Out:
#       bmi     region
# 0  27.900  southwest
# 1  33.770  southeast
# 2  33.000  southeast
# 3  22.705  northwest
# 4  28.880  northwest

# %%
#data.index = xrange(32561)
#data.index

# %%
data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(data, alpha = .5, figsize = (10, 10))
pass

# %%
data.corr()
# Out:
#                age       bmi  children   charges
# age       1.000000  0.109272  0.042469  0.299008
# bmi       0.109272  1.000000  0.012759  0.198341
# children  0.042469  0.012759  1.000000  0.067998
# charges   0.299008  0.198341  0.067998  1.000000

# %%
plt.plot(data['children'], data['age'], 'o', alpha = 0.05)
plt.xlabel('children')
plt.ylabel('age')
pass

# %%
data['sex'] == 'male'
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
# 5       False
# 6       False
# 7       False
# 8        True
# 9       False
# 10       True
# 11      False
# 12       True
# 13      False
# 14       True
# 15       True
# 16      False
# 17       True
# 18       True
# 19       True
# 20      False
# 21      False
# 22       True
# 23      False
# 24       True
# 25      False
# 26      False
# 27      False
# 28       True
# 29       True
#         ...
# 1308    False
# 1309     True
# 1310     True
# 1311    False
# 1312     True
# 1313    False
# 1314    False
# 1315     True
# 1316    False
# 1317     True
# 1318     True
# 1319    False
# 1320     True
# 1321     True
# 1322     True
# 1323    False
# 1324     True
# 1325     True
# 1326    False
# 1327     True
# 1328    False
# 1329     True
# 1330    False
# 1331    False
# 1332    False
# 1333     True
# 1334    False
# 1335    False
# 1336    False
# 1337    False
# ...

# %%
plt.figure(figsize = (10, 6))

plt.scatter(data[data['smoker'] == 'no']['age'],
            data[data['smoker'] == 'no']['charges'],
            alpha = 0.15,
            label = 'no smoke',
            color = 'b')

plt.scatter(data[data['smoker'] == 'yes']['age'],
            data[data['smoker'] == 'yes']['charges'],
            alpha = 0.15,
            label = 'smoker',
            color = 'r')

plt.xlabel('age')
plt.ylabel('charges')
plt.legend()
plt.grid()

# %%
np.random.seed(0)
education_num_rnd = data['age'] + np.random.rand(data.shape[0]) - .5

plt.figure(figsize = (10, 8))

plt.scatter(education_num_rnd[data['smoker'] == 'no'],
            data[data['smoker'] == 'no']['charges'],
            alpha = 0.15,
            label = 'no smoke',
            color = 'b')

plt.scatter(education_num_rnd[data['smoker'] == 'yes'],
            data[data['smoker'] == 'yes']['charges'],
            alpha = 0.15,
            label = 'smoker',
            color = 'r')

plt.xlabel('age')
plt.ylabel('charges')
plt.grid()

# %%
plt.figure(figsize = (10, 6))

plt.scatter(data[data['smoker'] == 'no']['bmi'],
            data[data['smoker'] == 'no']['charges'],
            alpha = 0.15,
            label = 'no smoke',
            color = 'b')

plt.scatter(data[data['smoker'] == 'yes']['bmi'],
            data[data['smoker'] == 'yes']['charges'],
            alpha = 0.15,
            label = 'smoker',
            color = 'r')

plt.xlabel('bmi')
plt.ylabel('charges')
plt.legend()
plt.grid()

# %%
data.describe(include = ['object'])
# Out:
#          sex smoker     region
# count   1338   1338       1338
# unique     2      2          4
# top     male     no  southeast
# freq     676   1064        364

# %%
data.describe(include = 'all')
# Out:
#                 age   sex          bmi     children smoker     region  \
# count   1338.000000  1338  1338.000000  1338.000000   1338       1338
# unique          NaN     2          NaN          NaN      2          4
# top             NaN  male          NaN          NaN     no  southeast
# freq            NaN   676          NaN          NaN   1064        364
# mean      39.207025   NaN    30.663397     1.094918    NaN        NaN
# std       14.049960   NaN     6.098187     1.205493    NaN        NaN
# min       18.000000   NaN    15.960000     0.000000    NaN        NaN
# 25%       27.000000   NaN    26.296250     0.000000    NaN        NaN
# 50%       39.000000   NaN    30.400000     1.000000    NaN        NaN
# 75%       51.000000   NaN    34.693750     2.000000    NaN        NaN
# max       64.000000   NaN    53.130000     5.000000    NaN        NaN
#
#              charges
# count    1338.000000
# unique           NaN
# top              NaN
# freq             NaN
# ...

# %%
data['region'].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
data['sex'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
data['smoker'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %% [markdown]
# # Готовим данные

# %%
categorical_columns = [c for c in data.columns if data[c].dtype.name == 'object']
numerical_columns   = [c for c in data.columns if data[c].dtype.name != 'object' and  c != 'charges']
print(categorical_columns)
print(numerical_columns)
# Out:
# ['sex', 'smoker', 'region']
# ['age', 'bmi', 'children']

# %%
for c in categorical_columns:
    print(c, data[c].unique())
# Out:
# sex ['female' 'male']
# smoker ['yes' 'no']
# region ['southwest' 'southeast' 'northwest' 'northeast']

# %% [markdown]
# ## Обрабатываем пропущенные значения
#
# Если данные содержат пропущенные значения, то имеется две простые альтернативы:
# - удалить столбцы с такими значениями (`data = data.dropna(axis = 1)`),
# - удалить строки с такими значениями (`data = data.dropna(axis = 0)`).
#
# После этого данных может стать совсем мало.
#
# Куда более эффективным (и в то же время по-прежнему простым) методом обычно является заполнение пропущенных значений для каждой количественной переменной их средним или медианным значением.
# Для категориальных признаков пропущенные значения можно заполнить самым популярным значением в столбце.

# %%
data.median(axis = 0)
# Out:
# age           39.000
# bmi           30.400
# children       1.000
# charges     9382.033
# dtype: float64

# %%
data = data.fillna(data.median(axis = 0), axis = 0)

# %%
data[numerical_columns].count(axis = 0)
# Out:
# age         1338
# bmi         1338
# children    1338
# dtype: int64

# %%
data[categorical_columns].count(axis = 0)
# Out:
# sex       1338
# smoker    1338
# region    1338
# dtype: int64

# %%
data['region'].describe()
# Out:
# count          1338
# unique            4
# top       southeast
# freq            364
# Name: region, dtype: object

# %%
type(data['region'].describe())
# Out:
# pandas.core.series.Series

# %%
data['region'].describe().top
# Out:
# 'southeast'

# %%
data['region'] = data['region'].fillna('southeast')

# %%
data['charges'].describe(include = [object])
# Out:
# count     1338.000000
# mean     13270.422265
# std      12110.011237
# min       1121.873900
# 25%       4740.287150
# 50%       9382.033000
# 75%      16639.912515
# max      63770.428010
# Name: charges, dtype: float64

# %%
data_describe = data.describe(include = [object])
for c in categorical_columns:
    data[c] = data[c].fillna(data_describe[c]['top'])

# %% [markdown]
# ## Векторизация
#
# Нужно что-то сделать с категориальными (номинальными) признаками

# %%
binary_columns    = [c for c in categorical_columns if data_describe[c]['unique'] == 2]
nonbinary_columns = [c for c in categorical_columns if data_describe[c]['unique'] > 2]
print(binary_columns, nonbinary_columns)
# Out:
# ['sex', 'smoker'] ['region']

# %%
data['charges'] = pd.cut(data['charges'],
                     bins=[0, 2000, 6000, 12000, 20000, 100000],
                     labels=["very small", "small", "normal", "big", "very big"])
data['charges'].describe()
data.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest      normal
# 1334   18  female  31.92         0     no  northeast       small
# 1335   18  female  36.85         0     no  southeast  very small
# 1336   21  female  25.80         0     no  southwest       small
# 1337   61  female  29.07         0    yes  northwest    very big

# %%
data['sex'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
data.at[data['sex'] == 'male', 'sex'] = 0
data.at[data['sex'] == 'female', 'sex'] = 1
data['sex'].describe()
# Out:
# count    1338.000000
# mean        0.494768
# std         0.500160
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# Name: sex, dtype: float64

# %%
data['smoker'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %% [markdown]
# К небинарными признакам применим метод _векторизации_,
# который заключается в следующем.
#
# Признак `j`, принимающий `s` значений, заменим на `s` признаков, принимащих значения `0` или `1`,
# в зависимости от того, чему равно значение исходного признака `j`.
#
# Например, в нашей задаче признак `race` принимает 5 различных значений:

# %%
data.at[data['smoker'] == 'no', 'smoker'] = 0
data.at[data['smoker'] == 'yes', 'smoker'] = 1
data['smoker'].describe()
# Out:
# count    1338.000000
# mean        0.204783
# std         0.403694
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: smoker, dtype: float64

# %%
data['region'].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %% [markdown]
# Заменим признак `region` 5 признаками: `region_southwest`, `region_southeast`, ..., `region_northeast`.
#
#  - Если признак `region` принимает значение `southwest`, то признак `region_southwest` равен `1`, а все остальные равны `0`.
#  - Если признак `region` принимает значение `southeast`, то признак `region_southeast` равен `1`, а все остальные равны `0`.
#  - и т.д.
#
# Такую векторизацию осуществляет в pandas метод `get_dummies`:

# %%
data_nonbinary = pd.get_dummies(data[nonbinary_columns])
print(data_nonbinary.columns)
# Out:
# Index(['region_northeast', 'region_northwest', 'region_southeast',
#        'region_southwest'],
#       dtype='object')

# %% [markdown]
# ## Нормализация количественных признаков
#
# Многие алгоритмы машинного обучения чувствительны к масштабированию данных.
# К таким алгоритмам, например, относится метод ближайших соседей, машина опорных векторов и др.
#
# В этом случае количественные признаки полезно _нормализовать_.
# Это можно делать разными способами.
# Например, каждый количественный признак приведем к нулевому среднему и единичному среднеквадратичному отклонению:

# %%
data_numerical = data[numerical_columns]
data_numerical.describe()
# Out:
#                age          bmi     children
# count  1338.000000  1338.000000  1338.000000
# mean     39.207025    30.663397     1.094918
# std      14.049960     6.098187     1.205493
# min      18.000000    15.960000     0.000000
# 25%      27.000000    26.296250     0.000000
# 50%      39.000000    30.400000     1.000000
# 75%      51.000000    34.693750     2.000000
# max      64.000000    53.130000     5.000000

# %%
data_numerical = (data_numerical - data_numerical.mean(axis = 0))/data_numerical.std(axis = 0)

# %%
data_numerical.describe()
# Out:
#                 age           bmi      children
# count  1.338000e+03  1.338000e+03  1.338000e+03
# mean  -1.810543e-16  1.553275e-15 -2.540735e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.509401e+00 -2.411110e+00 -9.082741e-01
# 25%   -8.688299e-01 -7.161386e-01 -9.082741e-01
# 50%   -1.473495e-02 -4.319265e-02 -7.873775e-02
# 75%    8.393600e-01  6.609101e-01  7.507986e-01
# max    1.764630e+00  3.684145e+00  3.239407e+00

# %% [markdown]
# ## Соединяем все в одну таблицу

# %%
data = pd.concat((data_numerical, data_nonbinary, data[binary_columns], data['charges']), axis = 1)
print(data.shape)
#print data.columns
# Out:
# (1338, 10)

# %%
data.describe()
# Out:
#                 age           bmi      children  region_northeast  \
# count  1.338000e+03  1.338000e+03  1.338000e+03       1338.000000
# mean  -1.810543e-16  1.553275e-15 -2.540735e-16          0.242152
# std    1.000000e+00  1.000000e+00  1.000000e+00          0.428546
# min   -1.509401e+00 -2.411110e+00 -9.082741e-01          0.000000
# 25%   -8.688299e-01 -7.161386e-01 -9.082741e-01          0.000000
# 50%   -1.473495e-02 -4.319265e-02 -7.873775e-02          0.000000
# 75%    8.393600e-01  6.609101e-01  7.507986e-01          0.000000
# max    1.764630e+00  3.684145e+00  3.239407e+00          1.000000
#
#        region_northwest  region_southeast  region_southwest          sex  \
# count       1338.000000       1338.000000       1338.000000  1338.000000
# mean           0.242900          0.272048          0.242900     0.494768
# std            0.428995          0.445181          0.428995     0.500160
# min            0.000000          0.000000          0.000000     0.000000
# ...

# %% [markdown]
# # X и y

# %%
X = data.drop(('charges'), axis = 1) # выбрасываем столбец 'charges'
y = data['charges']
feature_names = X.columns

# %%
type(feature_names)
# Out:
# pandas.core.indexes.base.Index

# %%
feature_names
# Out:
# Index(['age', 'bmi', 'children', 'region_northeast', 'region_northwest',
#        'region_southeast', 'region_southwest', 'sex', 'smoker'],
#       dtype='object')

# %%
print(X.shape)
print(y.shape)
N, d = X.shape
# Out:
# (1338, 9)
# (1338,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

N_train, _ = X_train.shape 
N_test,  _ = X_test.shape 

print(N_train, N_test)
# Out:
# 936 402

# %%
N_train+N_test
# Out:
# 1338

# %% [markdown]
# В библиотеке scikit-learn реализована масса алгоритмов машинного обучения.
#
# #### Некоторые алгоритмы машинного обучения, реализованные в scikit-learn:
#
#  Метод                                     |  Класс
# -------------------------------------------|--------------------------------------------
#  kNN – $k$ ближайших соседей               | `sklearn.neighbors.KNeighborsClassifier`
#  LDA – линейный дискриминантный анализ     | `sklearn.discriminant_analysis.LinearDiscriminantAnalysis`
#  QDA – квадратичный дискриминантный анализ | `sklearn.discriminant_analysis.QuadraticDiscriminantAnalysis`
#  Logistic – логистическая регрессия        | `sklearn.linear_model.LogisticRegression`
#  SVC – машина опорных векторов             | `sklearn.svm.SVC`
#  Tree – деревья решений                    | `sklearn.tree.DecisionTreeClassifier`
#  RF – случайный лес                        | `sklearn.ensemble.RandomForestClassifier`
#  ExtrRF – экстремально случайный лес       | ` `
#  AdaBoost – алгоритм AdaBoost              | `sklearn.ensemble.AdaBoostClassifier`
#  GBT – градиентный бустинг деревьев решений| `sklearn.ensemble.GradientBoostingClassifier`
#  Нейронные сети                            | ` `
#
#
#
#
# #### Основные методы классов, реализующих алгоритмы машинного обучения
# Все алгоритмы выполнены в виде классов, обладающих по крайней мере следующими методами:
#
#
#
#    Метод класса            |  Описание
#  --------------------------|-------------------------------------------------------------
#   `fit(X_train, y_train)`              |  обучение (тренировка) модели на обучающей выборке `X_train`, `y_train`
#   `predict(X)`             |  предсказание на данных `X`
#   `set_params(**params)`   |  установка параметров алгоритма
#   `get_params()`           |  чтение параметров алгоритма
#
#  Заметим, что параметры алгоритмов обучения можно задавать как в конструкторе класса, так и с помощью метода `set_params(**params)`.
#
#  #### Таблица наличия/отсутствия методов для основных алгоритмов машинного обучения:
#
#
#    Методы класса               | kNN | LDA | QDA | Logistic | SVC | Tree | RF | AdaBoost | GBT
#  ------------------------------|-----|-----|-----|----------|-----|------|----|----------|------
#   `fit(X, y)`                  |  +  |  +  |  +  |    +     |  +  |  +   | +  |    +     |  +
#   `predict(X)`                 |  +  |  +  |  +  |    +     |  +  |  +   | +  |    +     |  +
#   `predict_proba(X)`           |  +  |  +  |  +  |    +     |     |  +   | +  |    +     |  +
#   `predict_log_proba(X)`       |     |  +  |  +  |    +     |     |  +   | +  |    +     |  +
#   `score(X, y)`                |  +  |  +  |  +  |    +     |  +  |  +   | +  |    +     |  +
#   `decision_function(X)`       |     |  +  |  +  |    +     |  +  |      |    |    +     |  +
#   `transform(X)`               |     |  +  |     |    +     |     |  +   | +  |          |  +
#   `staged_decision_function(X)`|     |     |     |          |     |      |    |    +     |  +
#   `staged_predict(X)`          |     |     |     |          |     |      |    |    +     |  +
#   `staged_predict_proba(X)`    |     |     |     |          |     |      |    |    +     |  +
#   `staged_score(X, y)`         |     |     |     |          |     |      |    |    +     |  +
#   `set_params(**params)`       |  +  |  +  |  +  |    +     |  +  |  +   | +  |    +     |  +
#   `get_params()`               |  +  |  +  |  +  |    +     |  +  |  +   | +  |    +     |  +

# %% [markdown]
# # $k$NN

# %%
def try_k(k):
    knn = KNeighborsClassifier(n_neighbors = k)
    #knn.set_params(n_neighbors=10)
    knn.fit(X_train, y_train)
    return (1 - knn.score(X_train, y_train), 1 - knn.score(X_test, y_test))

# %%
ks = [1,3,7,11,15,19,23,27,31,35,39,43,47,51,55]
results_for_k = [try_k(k) for k in ks]
print(ks)
print(results_for_k)
# Out:
# [1, 3, 7, 11, 15, 19, 23, 27, 31, 35, 39, 43, 47, 51, 55]
# [(0.0, 0.27611940298507465), (0.14423076923076927, 0.2935323383084577), (0.21260683760683763, 0.2786069651741293), (0.22649572649572647, 0.27611940298507465), (0.2617521367521367, 0.2661691542288557), (0.28525641025641024, 0.2661691542288557), (0.29807692307692313, 0.2935323383084577), (0.30662393162393164, 0.2960199004975125), (0.33119658119658124, 0.3233830845771144), (0.33119658119658124, 0.3383084577114428), (0.3450854700854701, 0.34328358208955223), (0.3664529914529915, 0.34825870646766166), (0.36111111111111116, 0.35572139303482586), (0.3664529914529915, 0.3532338308457711), (0.37286324786324787, 0.36318407960199006)]

# %%
import operator

results_paired = {}
i = 0
while i < len(ks):
    results_paired[ks[i]] = results_for_k[i]
    i = i + 1

min_index, _ = min(enumerate([t for _, t in results_for_k]), key=operator.itemgetter(1))

print(results_paired)
print('Самое лучшее k: ', ks[min_index])
print('Ошибки на обучающей и тестовой выборках: ', results_for_k[min_index])
# Out:
# {1: (0.0, 0.27611940298507465), 3: (0.14423076923076927, 0.2935323383084577), 7: (0.21260683760683763, 0.2786069651741293), 11: (0.22649572649572647, 0.27611940298507465), 15: (0.2617521367521367, 0.2661691542288557), 19: (0.28525641025641024, 0.2661691542288557), 23: (0.29807692307692313, 0.2935323383084577), 27: (0.30662393162393164, 0.2960199004975125), 31: (0.33119658119658124, 0.3233830845771144), 35: (0.33119658119658124, 0.3383084577114428), 39: (0.3450854700854701, 0.34328358208955223), 43: (0.3664529914529915, 0.34825870646766166), 47: (0.36111111111111116, 0.35572139303482586), 51: (0.3664529914529915, 0.3532338308457711), 55: (0.37286324786324787, 0.36318407960199006)}
# Самое лучшее k:  15
# Ошибки на обучающей и тестовой выборках:  (0.2617521367521367, 0.2661691542288557)

# %%
plt.rcParams["figure.figsize"] = [12, 8]
axes = plt.gca()
axes.set_xscale('log', basex=10)
plt.plot(ks, [r[0] for r in results_for_k], color="r")
plt.plot(ks, [r[1] for r in results_for_k], color="b")

# %% [markdown]
# Красная линия, это ошибка на обучающей выборке. Синяя линия, это ошибка на тестовой выборке. Как возрастает k, так ошибки сходятся. На тестовой выборке, достигается минимум k=15. Для k > 15 ошибка на обучающей выборке становится больше ошибки на тестовой выборке. Могли бы поискать ещё лучшее k в окрестности 15, но вряд ли разница будет значительной.

# %% [markdown]
# # Нейронные сети

# %%
from sklearn.neural_network import MLPClassifier

# %%
def try_combination(alpha, hidden_layer_sizes):
    mlp_model = MLPClassifier(alpha = alpha, hidden_layer_sizes = hidden_layer_sizes,
                              solver = 'lbfgs', activation = 'logistic', random_state = 4)
    mlp_model.fit(X_train, y_train)
    y_train_pred = mlp_model.predict(X_train)
    y_test_pred = mlp_model.predict(X_test)
    return (np.mean(y_train_pred != y_train), np.mean(y_test_pred != y_test))

# %%
HL1_sizes = [X_train.shape[1]//2, X_train.shape[1], X_train.shape[1]*2]
HL2_sizes = [2, 8, 32]
alphas = np.logspace(-3, 2, 9)
plt.rcParams["figure.figsize"] = [8, 6]
plt.plot(range(9), alphas)

# %%
results = [[[try_combination(alpha, (L1, L2)) for alpha in alphas] for L2 in HL2_sizes] for L1 in HL1_sizes]

# %%
min_iL1 = 0
min_iL2 = 0
min_ialpha = 0
min_test_err = 1
min_train_err = 1
for iL1, vL1 in enumerate(results):
    for iL2, vL2 in enumerate(vL1):
        curr_min_ialpha, curr_min_value = min(enumerate(vL2), key=(lambda x: x[1][1]))
        if (min_test_err > curr_min_value[1]):
            min_train_err = curr_min_value[0]
            min_test_err = curr_min_value[1]
            min_ialpha = curr_min_ialpha
            min_iL2 = iL2
            min_iL1 = iL1

print('Наименьшая ошибка на тестовой выборке: ',  min_test_err)
print('Соответствующая ошибка на обучающей выборке: ',  min_train_err)
print(f'Соответствующие количества нейронов в первом слое {HL1_sizes[min_iL1]}, втором {HL2_sizes[min_iL2]} и альфа {alphas[min_ialpha]}.')
# Out:
# Наименьшая ошибка на тестовой выборке:  0.08955223880597014
# Соответствующая ошибка на обучающей выборке:  0.09188034188034189
# Соответствующие количества нейронов в первом слое 4, втором 32 и альфа 0.31622776601683794.

# %%
colors = [['#ff0000', '#aa0000', '#660000'], ['#00ff00', '#00aa00', '#006600'], ['#0000ff', '#0000aa', '#000066']]
plt.rcParams["figure.figsize"] = [16, 12]
axes = plt.gca()
axes.set_xscale('log', basex=10)

for i in range(len(HL1_sizes)):
    for j in range(len(HL2_sizes)):
        plt.plot(alphas, [train_err for train_err, _ in results[i][j]],
             color=colors[i][j], linestyle='dashed')
        plt.plot(alphas, [test_err for _, test_err in results[i][j]],
             color=colors[i][j], linestyle='solid',
             label=f'${HL1_sizes[i]}:${HL2_sizes[j]}')

plt.legend(loc='best')
plt.show()

# %% [markdown]
# При маленьких альфа переобучение очевидно, а результаты в зависимости от количества нейронов непредсказуемы. Слишком большие альфа не позволяют сети обучиться, и в результате получаем недообучение. Эти выводы не зависят от количества нейронов. При альфа около 0.33, получаем лучшее отношение между переобучением и недообучением. Трудно предсказать какое количество нейронов будет лучшим, но лучше избегать слишком маленькие и слишком большие значения, особенно при оптимальном альфа.

# %% [markdown]
# Попробуем с одним скрытым слоем.

# %%
HL_sizes = HL2_sizes + HL1_sizes
results1 = [[try_combination(alpha, (L,)) for alpha in alphas] for L in HL_sizes]

# %%
min_iL = 0
min_ialpha = 0
min_test_err = 1
min_train_err = 1
for iL, vL in enumerate(results1):
        curr_min_ialpha, curr_min_value = min(enumerate(vL), key=(lambda x: x[1][1]))
        if (min_test_err > curr_min_value[1]):
            min_train_err = curr_min_value[0]
            min_test_err = curr_min_value[1]
            min_ialpha = curr_min_ialpha
            min_iL = iL

print('Наименьшая ошибка на тестовой выборке: ',  min_test_err)
print('Соответствующая ошибка на обучающей выборке: ',  min_train_err)
print(f'Соответствующее количество нейронов {HL_sizes[min_iL]} и альфа {alphas[min_ialpha]}.')
# Out:
# Наименьшая ошибка на тестовой выборке:  0.08955223880597014
# Соответствующая ошибка на обучающей выборке:  0.08440170940170941
# Соответствующее количество нейронов 8 и альфа 0.07498942093324558.

# %%
colors1 = ['cyan', 'orange', 'magenta', 'red', 'green', 'blue']
plt.rcParams["figure.figsize"] = [16, 12]
axes = plt.gca()
axes.set_xscale('log', basex=10)

for i in range(len(HL_sizes)):
    plt.plot(alphas, [train_err for train_err, _ in results1[i]],
             color=colors1[i], linestyle='dashed')
    plt.plot(alphas, [test_err for _, test_err in results1[i]],
             color=colors1[i], linestyle='solid', label=f'neurons:{HL_sizes[i]}')

plt.legend(loc='best')
plt.show()

# %% [markdown]
# Наибольшая разница между ошибками на обучающей и тестовой выборках достигается при 18-32 нейронах и альфа, близким к нулю, что говорит о том, что при данном числе нейронов имеет место переобучение.

# %% [markdown]
# # Random Forest - preparing

# %%
from sklearn import ensemble
def print_forest_results(results, n_estimators):
    print(results)
    mi, _ = min(enumerate([err[1] for err in results]), key=operator.itemgetter(1))
    print()
    print(f'Лучшее количество деревьев {n_estimators[mi]}, соответствующая ошибка на обучающей выборке {results[mi][0]}, тестовой {results[mi][1]}')
    if len(results[0]) == 3:
        print(f'OOB ошибка {results[mi][2]}')

# %%
def plot_forest_results(results, n_estimators):
    plt.rcParams["figure.figsize"] = [12, 8]
    axes = plt.gca()
    axes.set_xscale('log', basex=4)

    plt.plot(n_estimators, [err[0] for err in results],
             color='red', linestyle='solid', marker='o', label='Train err')
    plt.plot(n_estimators, [err[1] for err in results],
             color='blue', linestyle='solid', marker='o', label='Test err')
    if len(results[0]) == 3:
        plt.plot(n_estimators, [err[2] for err in results],
                 color='green', linestyle='solid', marker='o', label='OOB err')

    plt.legend(loc='best')
    plt.show()

# %%
orig_X_train = X_train
orig_y_train = y_train
orig_X_test = X_test
orig_y_test = y_test

try_X_train = np.array([[-1, -1], [-1, 1], [1, -1], [1, 1]])
try_y_train = np.array([0, 1, 1, 0])
try_X_test = np.array([[-2, -0.5], [-0.7, 2.4], [0.1, -0.1], [0.01, 0.2]])
try_y_test = np.array([0, 1, 1, 0])

# %%
class DataSet:
    def __init__(self, X_train, y_train, X_test, y_test):
        self.X_train = X_train
        self.y_train = y_train
        self.X_test = X_test
        self.y_test = y_test

# %%
try_ds = DataSet(try_X_train, try_y_train, try_X_test, try_y_test)
real_ds = DataSet(X_train, y_train, X_test, y_test)

# %%
small_data = data.sample(n = 1000)
print(small_data.shape)
small_X = small_data.drop(('charges'), axis = 1)
small_y = small_data['charges']
small_X_train, small_X_test, small_y_train, small_y_test = train_test_split(small_X, small_y, test_size = 0.5, random_state = 141)
small_ds = DataSet(small_X_train, small_y_train, small_X_test, small_y_test)
# Out:
# (1000, 10)

# %%
# Определяем, для разработки или настоящие данные
ds = real_ds
#ds = small_ds
#ds = try_ds

# %%
ds.y_train.head()
# Out:
# 332         big
# 355    very big
# 138    very big
# 381    very big
# 292    very big
# Name: charges, dtype: category
# Categories (5, object): [very small < small < normal < big < very big]

# %%
print(ds.X_train.shape)
# Out:
# (936, 9)

# %% [markdown]
# ### Random Forest

# %%
def try_n_random_forests(X_train, y_train, X_test, y_test, n_estimators):
    en = ensemble.RandomForestClassifier(n_estimators = n_estimators, oob_score = True)
    en.fit(X_train, y_train)
    err_train = np.mean(y_train != en.predict(X_train))
    err_oob = 1 - en.oob_score_
    err_test = np.mean(y_test != en.predict(X_test))
    return (err_train, err_test, err_oob)

# %%
n_estimators = [2, 4, 6, 8, 10, 16, 32, 64, 128, 256, 512, 1024, 2048]

results_for_random_forests = [try_n_random_forests(ds.X_train, ds.y_train, ds.X_test, ds.y_test, ne) \
                            for ne in n_estimators]
# Out:
# C:\Users\Ravie\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:453: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\Users\Ravie\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:458: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\Users\Ravie\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:453: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\Users\Ravie\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:458: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# ...

# %%
print_forest_results(results_for_random_forests, n_estimators)
# Out:
# [(0.09508547008547008, 0.27114427860696516, 0.4871794871794872), (0.035256410256410256, 0.19154228855721392, 0.3685897435897436), (0.030982905982905984, 0.14427860696517414, 0.2799145299145299), (0.014957264957264958, 0.15422885572139303, 0.22008547008547008), (0.01282051282051282, 0.1417910447761194, 0.20192307692307687), (0.008547008547008548, 0.13681592039800994, 0.18055555555555558), (0.004273504273504274, 0.11940298507462686, 0.1495726495726496), (0.0, 0.11940298507462686, 0.1527777777777778), (0.0, 0.11691542288557213, 0.14850427350427353), (0.0, 0.11940298507462686, 0.14209401709401714), (0.0, 0.11940298507462686, 0.13354700854700852), (0.0, 0.12935323383084577, 0.13782051282051277), (0.0, 0.12437810945273632, 0.1399572649572649)]
#
# Лучшее количество деревьев 128, соответствующая ошибка на обучающей выборке 0.0, тестовой 0.11691542288557213
# OOB ошибка 0.14850427350427353

# %%
plot_forest_results(results_for_random_forests, n_estimators)

# %% [markdown]
# OOB ошибка хорошо приближает тестовую, которая много выше обучающей. Хотя это так, это не похоже на класическое переобучение, потому что, графики выглядят более менее похоже, только сдвинуты по y. Это значит, что с уменьшением ошибки на обучающей выборке уменьшается и ошибка на тестовой, но она просто не может достичь такого уровня.

# %% [markdown]
# # Extremely Randomized Trees

# %%
def try_n_extremely_randomized_forests(X_train, y_train, X_test, y_test, n_estimators):
    en = ensemble.ExtraTreesClassifier(n_estimators = n_estimators)
    en.fit(X_train, y_train)
    err_train = np.mean(y_train != en.predict(X_train))
    err_test = np.mean(y_test != en.predict(X_test))
    return (err_train, err_test)

# %%
n_estimators = [2, 4, 6, 8, 10, 16, 32, 64, 128, 256, 512, 1024, 2048]

results_for_extremely_randomized_forests = [try_n_extremely_randomized_forests(ds.X_train, ds.y_train, ds.X_test, ds.y_test, ne) \
                            for ne in n_estimators]

# %%
print_forest_results(results_for_extremely_randomized_forests, n_estimators)
# Out:
# [(0.0, 0.24875621890547264), (0.0, 0.22885572139303484), (0.0, 0.19651741293532338), (0.0, 0.18407960199004975), (0.0, 0.1691542288557214), (0.0, 0.1691542288557214), (0.0, 0.1517412935323383), (0.0, 0.15920398009950248), (0.0, 0.13681592039800994), (0.0, 0.1417910447761194), (0.0, 0.14676616915422885), (0.0, 0.14427860696517414), (0.0, 0.14676616915422885)]
#
# Лучшее количество деревьев 128, соответствующая ошибка на обучающей выборке 0.0, тестовой 0.13681592039800994

# %%
plot_forest_results(results_for_extremely_randomized_forests, n_estimators)

# %% [markdown]
# # AdaBoost

# %%
def try_n_adaboost(X_train, y_train, X_test, y_test, n_estimators):
    en = ensemble.AdaBoostClassifier(n_estimators = n_estimators)
    en.fit(X_train, y_train)
    err_train = np.mean(y_train != en.predict(X_train))
    err_test = np.mean(y_test != en.predict(X_test))
    return (err_train, err_test)

# %%
n_estimators = [2, 4, 6, 8, 10, 16, 32, 64, 128, 256, 512, 1024, 2048]

results_for_adaboost = [try_n_adaboost(ds.X_train, ds.y_train, ds.X_test, ds.y_test, ne) \
                            for ne in n_estimators]

# %%
print_forest_results(results_for_adaboost, n_estimators)
# Out:
# [(0.3215811965811966, 0.2960199004975124), (0.2938034188034188, 0.2860696517412935), (0.44871794871794873, 0.4427860696517413), (0.5149572649572649, 0.5074626865671642), (0.5651709401709402, 0.5373134328358209), (0.5566239316239316, 0.5398009950248757), (0.561965811965812, 0.5447761194029851), (0.5566239316239316, 0.5522388059701493), (0.5844017094017094, 0.572139303482587), (0.5982905982905983, 0.5895522388059702), (0.6282051282051282, 0.6218905472636815), (0.6431623931623932, 0.6343283582089553), (0.6399572649572649, 0.6293532338308457)]
#
# Лучшее количество деревьев 4, соответствующая ошибка на обучающей выборке 0.2938034188034188, тестовой 0.2860696517412935

# %%
plot_forest_results(results_for_adaboost, n_estimators)

# %% [markdown]
# Здесь мы видим, что при увеличении количества деревьев ошибки на тестовой и обучающей выборках растут.
# Ошибка на тестовой выборке всегда оказывается меньше ошибки на обучающей выборке и как следствие переобучения практически нет. Но избавление от него такой ценой вряд ли имеет смысл.
# Судя по всему, на этих данных метод adaboost работает не слишком успешно, и следует использовать один из ранее рассмотренных двух алгоритмов.

# %% [markdown]
# # GBT

# %%
def try_n_gbt(X_train, y_train, X_test, y_test, n_estimators):
    en = ensemble.GradientBoostingClassifier(n_estimators = n_estimators)
    en.fit(X_train, y_train)
    err_train = np.mean(y_train != en.predict(X_train))
    err_test = np.mean(y_test != en.predict(X_test))
    return (err_train, err_test)

# %%
n_estimators = [2, 4, 6, 8, 10, 16, 32, 64, 128, 256, 512, 1024, 2048]

results_for_gbt = [try_n_gbt(ds.X_train, ds.y_train, ds.X_test, ds.y_test, ne) \
                            for ne in n_estimators]

# %%
print_forest_results(results_for_gbt, n_estimators)
# Out:
# [(0.1858974358974359, 0.17661691542288557), (0.17414529914529914, 0.16417910447761194), (0.16880341880341881, 0.15920398009950248), (0.16987179487179488, 0.15920398009950248), (0.15598290598290598, 0.15422885572139303), (0.14636752136752137, 0.14925373134328357), (0.10790598290598291, 0.13681592039800994), (0.0811965811965812, 0.13432835820895522), (0.0438034188034188, 0.1318407960199005), (0.002136752136752137, 0.1318407960199005), (0.0, 0.13930348258706468), (0.0, 0.14427860696517414), (0.0, 0.14925373134328357)]
#
# Лучшее количество деревьев 128, соответствующая ошибка на обучающей выборке 0.0438034188034188, тестовой 0.1318407960199005

# %%
plot_forest_results(results_for_gbt, n_estimators)

# %% [markdown]
# При малом количестве деревьев мы видим, что переобучения не происходит. При количестве деревьев от 8 и больше, начинается переобучение. Данный метод по сравнению с предыдущими рассмотренными методами показал довольно хорошие результаты. Переобучение с ростом числа деревьев довольно резко растёт (и в целом довольно значительно, за исключением случая с малым числом деревьев), а ошибка на тестовой выборке улучшается не столь быстро.
#
# Таким образом, победителем среди рассмотренных методов вышел метод нейронных сетей: наилучшая ошибка 0.0895 на тестовой выборке при использовании однослойной нейронной сети с параметром alpha равным 0.075 достигается при 8 нейронах.

# %% [markdown]
# # PCA - метод главных компонент

# %% [markdown]
# ### Обработаем все оригинальные данные

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=5, svd_solver='arpack')
pca_train = pca.fit_transform(X_train)
pca_test = pca.fit_transform(X_test)
pca
# Out:
# PCA(copy=True, iterated_power='auto', n_components=5, random_state=None,
#   svd_solver='arpack', tol=0.0, whiten=False)

# %%
print(pca_train.shape)
# Out:
# (936, 5)

# %%
from sklearn.neural_network import MLPClassifier
mlp_model = MLPClassifier(hidden_layer_sizes = (100,), solver = 'lbfgs', 
                          activation = 'logistic', random_state = 42)
mlp_model.fit(pca_train, y_train)
y_train_pred = mlp_model.predict(pca_train)
y_test_pred = mlp_model.predict(pca_test)
print(np.mean(y_train != y_train_pred), np.mean(y_test != y_test_pred))
# Out:
# 0.25854700854700857 0.7437810945273632

# %%
mlp_model = MLPClassifier(hidden_layer_sizes = (100,), solver = 'lbfgs', 
                          activation = 'logistic', random_state = 42)
mlp_model.fit(X_train, y_train)
y_train_pred = mlp_model.predict(X_train)
y_test_pred = mlp_model.predict(X_test)
train_err_without_PCA=np.mean(y_train != y_train_pred)
test_err_without_PCA=np.mean(y_test != y_test_pred)


num_arr = [i+1 for i in range(9)]
train_err_PCA = []
test_err_PCA = []
test_err = []
train_err = []
for num in num_arr:
    pca = PCA(n_components=int(num))
    pca_train = pca.fit_transform(X_train)
    pca_test = pca.fit_transform(X_test)
    
    mlp_model = MLPClassifier(hidden_layer_sizes = (100,), solver = 'lbfgs', 
                          activation = 'logistic', random_state = 42)
    mlp_model.fit(pca_train, y_train)

    y_train_pred = mlp_model.predict(pca_train)
    y_test_pred = mlp_model.predict(pca_test)

    train_err_PCA.append(np.mean(y_train != y_train_pred))
    test_err_PCA.append(np.mean(y_test != y_test_pred))
    train_err.append(train_err_without_PCA)
    test_err.append(test_err_without_PCA)
    
plt.semilogx(num_arr, train_err_PCA, 'b-o', label = 'train')
plt.semilogx(num_arr, test_err_PCA, 'r-o', label = 'test')
plt.semilogx(num_arr, train_err, 'g-o', label = 'train without PCA')
plt.semilogx(num_arr, test_err, 'y-o', label = 'test without PCA')
plt.xlim([np.max(num_arr), np.min(num_arr)])
plt.title('Error vs. number of components')
plt.xlabel('number')
plt.ylabel('error')
plt.legend()
pass

# %% [markdown]
# Как видно из графиков применение PCA не улучшает результатов обучения.
